# %% [markdown]
# <a href="https://colab.research.google.com/github/jumorenop/MetNumUN2022II/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

import yfinance as yf

msft = yf.Ticker("MSFT")

print(msft.info)

data = msft.history(start="2018-01-01",  end="2019-01-01")
data
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
